# %%
import dataclasses

import jax

from openpi.models import model as _model
from openpi.policies import droid_policy
from openpi.policies import policy_config as _policy_config
from openpi.shared import download
from openpi.training import config as _config
from openpi.training import data_loader as _data_loader

# %% [markdown]
# # Policy inference
#
# The following example shows how to create a policy from a checkpoint and run inference on a dummy example.

# %%
config = _config.get_config("pi0_fast_droid")
checkpoint_dir = download.maybe_download("s3://openpi-assets/checkpoints/pi0_fast_droid")

# Create a trained policy.
policy = _policy_config.create_trained_policy(config, checkpoint_dir)

# Run inference on a dummy example. This example corresponds to observations produced by the DROID runtime.
example = droid_policy.make_droid_example()
result = policy.infer(example)

# Delete the policy to free up memory.
del policy

print("Actions shape:", result["actions"].shape)
# Out:
#   0%|          | 0.00/10.1G [00:00<?, ?iB/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: openpi-assets.s3.us-west-1.amazonaws.com. Connection pool size: 16
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: openpi-assets.s3.us-west-1.amazonaws.com. Connection pool size: 16
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: openpi-assets.s3.us-west-1.amazonaws.com. Connection pool size: 16
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: openpi-assets.s3.us-west-1.amazonaws.com. Connection pool size: 16
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: openpi-assets.s3.us-west-1.amazonaws.com. Connection pool size: 16
#   0%|          | 0.00/4.07M [00:00<?, ?iB/s]
# processor_config.json:   0%|          | 0.00/253 [00:00<?, ?B/s]
# processing_action_tokenizer.py:   0%|          | 0.00/6.14k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/physical-intelligence/fast:
# - processing_action_tokenizer.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tokenizer_config.json:   0%|          | 0.00/322 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/687k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.00 [00:00<?, ?B/s]
# Some kwargs in processor config are unused and will not have any effect: time_horizon, scale, min_token, vocab_size, action_dim.
# Some kwargs in processor config are unused and will not have any effect: time_horizon, scale, min_token, vocab_size, action_dim.
# Actions shape: (10, 8)

# %% [markdown]
# # Working with a live model
#
#
# The following example shows how to create a live model from a checkpoint and compute training loss. First, we are going to demonstrate how to do it with fake data.

# %%
config = _config.get_config("pi0_aloha_sim")

checkpoint_dir = download.maybe_download("s3://openpi-assets/checkpoints/pi0_aloha_sim")
key = jax.random.key(0)

# Create a model from the checkpoint.
model = config.model.load(_model.restore_params(checkpoint_dir / "params"))

# We can create fake observations and actions to test the model.
obs, act = config.model.fake_obs(), config.model.fake_act()

# Sample actions from the model.
loss = model.compute_loss(key, obs, act)
print("Loss shape:", loss.shape)
# Out:
#   0%|          | 0.00/11.2G [00:00<?, ?iB/s]
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: openpi-assets.s3.us-west-1.amazonaws.com. Connection pool size: 16
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: openpi-assets.s3.us-west-1.amazonaws.com. Connection pool size: 16
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: openpi-assets.s3.us-west-1.amazonaws.com. Connection pool size: 16
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: openpi-assets.s3.us-west-1.amazonaws.com. Connection pool size: 16
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: openpi-assets.s3.us-west-1.amazonaws.com. Connection pool size: 16
# Loss shape: (1, 50)

# %% [markdown]
# Now, we are going to create a data loader and use a real batch of training data to compute the loss.

# %%
# Reduce the batch size to reduce memory usage.
config = dataclasses.replace(config, batch_size=1)

# Load a single batch of data. This is the same data that will be used during training.
# NOTE: In order to make this example self-contained, we are skipping the normalization step
# since it requires the normalization statistics to be generated using `compute_norm_stats`.
loader = _data_loader.create_data_loader(config, num_batches=1, skip_norm_stats=True)
obs, act = next(iter(loader))

# Sample actions from the model.
loss = model.compute_loss(key, obs, act)

# Delete the model to free up memory.
del model

print("Loss shape:", loss.shape)
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Fetching 106 files:   0%|          | 0/106 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       4 # Load a single batch of data. This is the same data that will be used during training.
#       5 # NOTE: In order to make this example self-contained, we are skipping the normalization step
#       6 # since it requires the normalization statistics to be generated using `compute_norm_stats`.
#       7 loader = _data_loader.create_data_loader(config, num_batches=1, skip_norm_stats=True)
# ----> 8 obs, act = next(iter(loader))
#      10 # Sample actions from the model.
#      11 loss = model.compute_loss(key, obs, act)
#
# File ~/code/openpi/src/openpi/training/data_loader.py:177, in create_data_loader.<locals>.DataLoaderImpl.__iter__(self)
#     176 def __iter__(self):
# --> 177     for batch in self._data_loader:
#     178         yield _model.Observation.from_dict(batch), batch["actions"]
#
# File ~/code/openpi/src/openpi/training/data_loader.py:261, in TorchDataLoader.__iter__(self)
#     259     break  # We've exhausted the dataset. Create a new iterator and start over.
#     260 num_items += 1
# --> 261 yield jax.tree.map(lambda x: jax.make_array_from_process_local_data(self._sharding, x), batch)
#
# File ~/code/openpi/.venv/lib/python3.11/site-packages/jax/_src/tree.py:155, in map(f, tree, is_leaf, *rest)
#     115 def map(f: Callable[..., Any],
#     116         tree: Any,
#     117         *rest: Any,
#     118         is_leaf: Callable[[Any], bool] | None = None) -> Any:
#     119   """Maps a multi-input function over pytree args to produce a new pytree.
#     120
#     121   Args:
#    (...)
#     153     - :func:`jax.tree.reduce`
#     154   """
# --> 155   return tree_util.tree_map(f, tree, *rest, is_leaf=is_leaf)
#
# File ~/code/openpi/.venv/lib/python3.11/site-packages/jax/_src/tree_util.py:358, in tree_map(f, tree, is_leaf, *rest)
#     356 leaves, treedef = tree_flatten(tree, is_leaf)
#     357 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 358 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File ~/code/openpi/.venv/lib/python3.11/site-packages/jax/_src/tree_util.py:358, in <genexpr>(.0)
#     356 leaves, treedef = tree_flatten(tree, is_leaf)
#     357 all_leaves = [leaves] + [treedef.flatten_up_to(r) for r in rest]
# --> 358 return treedef.unflatten(f(*xs) for xs in zip(*all_leaves))
#
# File ~/code/openpi/src/openpi/training/data_loader.py:261, in TorchDataLoader.__iter__.<locals>.<lambda>(x)
#     259     break  # We've exhausted the dataset. Create a new iterator and start over.
#     260 num_items += 1
# --> 261 yield jax.tree.map(lambda x: jax.make_array_from_process_local_data(self._sharding, x), batch)
#
# File ~/code/openpi/.venv/lib/python3.11/site-packages/jax/_src/array.py:910, in make_array_from_process_local_data(sharding, local_data, global_shape)
#     908 # pyformat: enable
#     909 if xla_bridge.process_count() == 1:
# --> 910   return api.device_put(local_data, sharding)
#     912 # TODO(sandler): consider supporting partially specified global_shape or
#     913 # making local_to_global_shape available in the api.
#     914 local_shape = local_data.shape
#
# File ~/code/openpi/.venv/lib/python3.11/site-packages/jax/_src/api.py:2300, in device_put(x, device, src, donate, may_alias)
#    2297     copy_semantics.append(dispatch.CopySemantics.COPY)
#    2299 for xf, d in zip(x_flat, device_flat):  # type: ignore
# -> 2300   _check_sharding(shaped_abstractify(xf), d)
#    2301 out_flat = dispatch.device_put_p.bind(
#    2302     *x_flat, devices=device_flat, srcs=src_flat,
#    2303     copy_semantics=copy_semantics)
#    2304 return tree_unflatten(treedef, out_flat)
#
# File ~/code/openpi/.venv/lib/python3.11/site-packages/jax/_src/api.py:2218, in _check_sharding(aval, s)
#    2216   aval = core.token_shaped_array
#    2217 if not isinstance(s, PmapSharding):
# -> 2218   pjit.pjit_check_aval_sharding(
#    2219       (s,), (aval,), None, "device_put args", allow_uneven_sharding=False)
#    2220 s.shard_shape(aval.shape)
#
# File ~/code/openpi/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:1440, in pjit_check_aval_sharding(shardings, flat_avals, names, what_aval, allow_uneven_sharding)
#    1438 for i, size in enumerate(num_ways_dim_sharded):
#    1439   if not allow_uneven_sharding and shape[i] % size != 0:
# -> 1440     raise ValueError(f"One of {what_aval}{name_str} was given the sharding "
#    1441                      f"of {s}, which implies that "
#    1442                      f"the global size of its dimension {i} should be "
#    1443                      f"divisible by {size}, but it is equal to {shape[i]} "
#    1444                      f"(full shape: {shape})")
#
# ValueError: One of device_put args was given the sharding of NamedSharding(mesh=Mesh('B': 4), spec=PartitionSpec('B',), memory_kind=device), which implies that the global size of its dimension 0 should be divisible by 4, but it is equal to 2 (full shape: (2, 50, 32))
